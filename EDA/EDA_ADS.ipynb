# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("LA_Nevada_2019_20.csv")
df = df[df['Year']==2019]
df = df[df['is_day']==True]

# %%
df[df['Year']==2019].shape
# Out:
# (26792, 13)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Hour', 'Minute', 'DHI', 'DNI', 'GHI',
#        'Relative Humidity', 'Solar Zenith Angle', 'Temperature', 'is_day',
#        'Datetime'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26792 entries, 42 to 52515
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                26792 non-null  int64
#  1   Month               26792 non-null  int64
#  2   Day                 26792 non-null  int64
#  3   Hour                26792 non-null  int64
#  4   Minute              26792 non-null  int64
#  5   DHI                 26792 non-null  int64
#  6   DNI                 26792 non-null  int64
#  7   GHI                 26792 non-null  int64
#  8   Relative Humidity   26792 non-null  float64
#  9   Solar Zenith Angle  26792 non-null  float64
#  10  Temperature         26792 non-null  float64
#  11  is_day              26792 non-null  bool
#  12  Datetime            26792 non-null  object
# dtypes: bool(1), float64(3), int64(8), object(1)
# memory usage: 2.7+ MB

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26792 entries, 42 to 52515
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                26792 non-null  int64
#  1   Month               26792 non-null  int64
#  2   Day                 26792 non-null  int64
#  3   Hour                26792 non-null  int64
#  4   Minute              26792 non-null  int64
#  5   DHI                 26792 non-null  int64
#  6   DNI                 26792 non-null  int64
#  7   GHI                 26792 non-null  int64
#  8   Relative Humidity   26792 non-null  float64
#  9   Solar Zenith Angle  26792 non-null  float64
#  10  Temperature         26792 non-null  float64
#  11  is_day              26792 non-null  bool
#  12  Datetime            26792 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(8)
# memory usage: 2.7 MB

# %%
df.describe()
# Out:
#           Year         Month           Day          Hour        Minute  \
# count  26792.0  26792.000000  26792.000000  26792.000000  26792.000000
# mean    2019.0      6.457525     15.728202     11.969655     25.040311
# std        0.0      3.239991      8.797734      3.672262     17.094761
# min     2019.0      1.000000      1.000000      5.000000      0.000000
# 25%     2019.0      4.000000      8.000000      9.000000     10.000000
# 50%     2019.0      6.000000     16.000000     12.000000     30.000000
# 75%     2019.0      9.000000     23.000000     15.000000     40.000000
# max     2019.0     12.000000     31.000000     20.000000     50.000000
#
#                 DHI           DNI           GHI  Relative Humidity  \
# count  26792.000000  26792.000000  26792.000000       26792.000000
# mean      99.262504    601.020790    455.095327          23.742811
# std       82.428428    354.882754    314.098524          16.290496
# min        0.000000      0.000000      0.000000           3.160000
# 25%       56.000000    276.000000    172.000000          11.530000
# 50%       82.000000    753.000000    446.000000          18.740000
# 75%      111.000000    906.000000    718.000000          31.992500
# max      499.000000   1037.000000   1063.000000          92.140000
#
#        Solar Zenith Angle   Temperature
# count        26792.000000  26792.000000
# mean            58.389402     24.550657
# std             21.029689     10.715733
# min             12.730000     -1.100000
# 25%             43.260000     15.700000
# 50%             59.540000     24.600000
# 75%             73.970000     33.600000
# max            103.230000     44.900000

# %%
df.isnull().sum()   # No Null Value
# Out:
# Year                  0
# Month                 0
# Day                   0
# Hour                  0
# Minute                0
# DHI                   0
# DNI                   0
# GHI                   0
# Relative Humidity     0
# Solar Zenith Angle    0
# Temperature           0
# is_day                0
# Datetime              0
# dtype: int64

# %%
plt.figure(figsize=(20,8))
df['GHI'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,9))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df['Temperature'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Relative Humidity'].plot()
# Out:
# <AxesSubplot:>

# %%
# !pip install pandas pandas-profiling
# Out:
# Requirement already satisfied: pandas in c:\users\vishal\anaconda32\lib\site-packages (1.4.4)
# Requirement already satisfied: pandas-profiling in c:\users\vishal\anaconda32\lib\site-packages (3.6.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\vishal\anaconda32\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vishal\anaconda32\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\vishal\anaconda32\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: ydata-profiling in c:\users\vishal\anaconda32\lib\site-packages (from pandas-profiling) (4.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\vishal\anaconda32\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (2.13.3)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (0.13.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (6.0)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (0.7.5)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (0.12.3)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (0.11.2)
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (2.28.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (3.1.2)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (1.10.7)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (4.64.1)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (4.3.1)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (0.1.12)
# Requirement already satisfied: multimethod<1.10,>=1.4 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in c:\users\vishal\anaconda32\lib\site-packages (from ydata-profiling->pandas-profiling) (3.5.2)
# Requirement already satisfied: pillow in c:\users\vishal\anaconda32\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (9.2.0)
# Requirement already satisfied: PyWavelets in c:\users\vishal\anaconda32\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.3.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\vishal\anaconda32\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (0.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\vishal\anaconda32\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (2.8.4)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\vishal\anaconda32\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (21.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vishal\anaconda32\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.1.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vishal\anaconda32\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\vishal\anaconda32\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vishal\anaconda32\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vishal\anaconda32\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vishal\anaconda32\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (21.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\vishal\anaconda32\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\vishal\anaconda32\lib\site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas-profiling) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\vishal\anaconda32\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vishal\anaconda32\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vishal\anaconda32\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vishal\anaconda32\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (3.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\vishal\anaconda32\lib\site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.2)
# Requirement already satisfied: colorama in c:\users\vishal\anaconda32\lib\site-packages (from tqdm<4.65,>=4.48.2->ydata-profiling->pandas-profiling) (0.4.5)

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
profile.to_file('eda_report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
